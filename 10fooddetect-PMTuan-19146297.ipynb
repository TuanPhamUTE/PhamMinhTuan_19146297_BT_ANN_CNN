# %%
# Gọi các thư viện cần thiết 
import numpy as np
import pandas as pd # Xu lý bảng
import seaborn as sns # Vẽ biểu đồ thị của dữ liệu
import matplotlib.pyplot as plt 
from sklearn.preprocessing import StandardScaler # Xử lý chuẩn hóa dữ liệu
from sklearn.model_selection import train_test_split # Chia dữ liệu ra làm 2 phần
from keras.layers import Dense, Activation, Dropout, BatchNormalization, LSTM    # LSTM  biên dạng ANN, BatchNormalization: cho nhỏ lại
from keras.models import Sequential
from tensorflow.keras.utils import to_categorical # Sử dung để làm nổi đối tượng cần phân loại
from keras import callbacks 
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score # Để đo lường

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
# Load 1 image
img = image.load_img("../input/10typeoffooddatasets/Images/Train/Banh beo/1.jpg")
plt.imshow(img)

# %%
image_generator = ImageDataGenerator(rescale=1/255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=32,
                                                 directory='../input/10typeoffooddatasets/Images/Train',
                                                 shuffle=True,
                                                 target_size=(100, 100), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=32,
                                                 directory='../input/10typeoffooddatasets/Images/Validate',
                                                 shuffle=True,
                                                 target_size=(100, 100), 
                                                 subset="validation",
                                                 class_mode='categorical')

# %%
def ham_tao_nhan(x,num):
    for i in x:   
        image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
        target_size= (100,100))
        image=np.array(image)
        data.append(image)
        labels.append(num)

# %%
# Reshape data
import glob
banhbeo = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh beo/*.*')
banhbotloc = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh bot loc/*.*')
banhcan = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh can/*.*')
banhcanh = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh canh/*.*')
banhchung = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh chung/*.*')
banhcuon = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh cuon/*.*')
banhduc = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh duc/*.*')
banhgio = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh gio/*.*')
banhkhot = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh khot/*.*')
banhmi = glob.glob('../input/10typeoffooddatasets/Images/Train/Banh mi/*.*')



data = []
labels = []
    
# Gọi các hàm
ham_tao_nhan(banhbeo,0)
ham_tao_nhan(banhbotloc,1)
ham_tao_nhan(banhcan,2)
ham_tao_nhan(banhcanh,3)
ham_tao_nhan(banhchung,4)
ham_tao_nhan(banhcuon,5)
ham_tao_nhan(banhduc,6)
ham_tao_nhan(banhgio,7)
ham_tao_nhan(banhkhot,8)
ham_tao_nhan(banhmi,9)

data = np.array(data)
labels = np.array(labels)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2,random_state=42)

# %% [markdown]
# import glob
# banhbeo = glob.glob('../input/vietnamese-foods/Images/Train/Banh beo/*.*')
# banhbotloc = glob.glob('../input/vietnamese-foods/Images/Train/Banh bot loc/*.*')
# banhcan = glob.glob('../input/vietnamese-foods/Images/Train/Banh can/*.*')
# banhcanh = glob.glob('../input/vietnamese-foods/Images/Train/Banh canh/*.*')
# banhchung = glob.glob('../input/vietnamese-foods/Images/Train/Banh chung/*.*')
# banhcuon = glob.glob('../input/vietnamese-foods/Images/Train/Banh cuon/*.*')
# banhduc = glob.glob('../input/vietnamese-foods/Images/Train/Banh duc/*.*')
# banhgio = glob.glob('../input/vietnamese-foods/Images/Train/Banh gio/*.*')
# banhkhot = glob.glob('../input/vietnamese-foods/Images/Train/Banh khot/*.*')
# banhmi = glob.glob('../input/vietnamese-foods/Images/Train/Banh mi/*.*')
#
#
# data = []
# labels = []
#
# for i in banhbeo:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(0)
# for i in banhbotloc:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(1)
# for i in banhcan:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(2)
# for i in banhcanh:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(3)
# for i in banhchung:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(4)
# for i in banhcuon:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(5)
# for i in banhduc:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(1)
# for i in banhgio:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(0)
# for i in banhkhot:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(1)
# for i in banhmi:
#     image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb',
#     target_size= (150,150))
#     image=np.array(image)
#     data.append(image)
#     labels.append(0)
#
#
#
#
# data = np.array(data)
# labels = np.array(labels)
#
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(data, labels,random_state=0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
# Thực hiện tiền xử lý dữ liệu
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train/=255
X_test/=255

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
print(y_train)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape

# %%
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(100,100,3)))
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lan tich chap
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lan tich chap
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(256,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 256 lan tich chap
model.add(Conv2D(256,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))

model.add(Conv2D(512,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 512 lan tich chap
model.add(Conv2D(512,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))

from keras.layers import Dense, Activation, Flatten
model.add(Flatten())
model.add(Dense(128, activation = 'relu', kernel_initializer='he_uniform'))
model.add(Dense(10))
model.summary()

# %%
# Huận luyện mô hình 
model.compile(loss='mse',optimizer=RMSprop(),metrics=['accuracy'])
history = model.fit(X_train, y_train, epochs =50, batch_size =128,validation_data=(X_test,y_test) , verbose = 1)

# %%
# Đánh giá độ chính xác của mô hình
score = model.evaluate(X_test,y_test,verbose=0)
print('Sai số kiểm tra là: ',score[0])
print('Độ chính xác kiểm tra là: ',score[1])

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
from tensorflow.keras.models import load_model
model.save('Final.h5')
model_CNN = load_model('Final.h5')

# %%
# ham_tao_nhan(banhbeo,0)
# ham_tao_nhan(banhbotloc,1)
# ham_tao_nhan(banhcan,2)
# ham_tao_nhan(banhcanh,3)
# ham_tao_nhan(banhchung,4)
# ham_tao_nhan(banhcuon,5)
# ham_tao_nhan(banhduc,6)
# ham_tao_nhan(banhgio,7)
# ham_tao_nhan(banhkhot,8)
# ham_tao_nhan(banhmi,9)


from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = "../input/10typeoffooddatasets/Images/Test/Banh beo/142.jpg"

predict = ['Bánh Bèo','Bánh Bột Lọc','Bánh Can','Bánh Canh','Bánh Chưng','Bánh Cuốn','Bánh Đúc','Bánh Giò','Bánh Khọt','Bánh Mì']
predict = np.array(predict)
img = load_img(filename,target_size=(100,100))
plt.imshow(img)

img = img_to_array(img)
img = img.reshape(1,100,100,3)
img = img.astype('float32')
img = img/255


result = np.argmax(model_CNN.predict(img),axis=-1)
predict[result]
